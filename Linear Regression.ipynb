# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt


#read data
df = pd.read_csv('challenge_dataset.txt')
df.columns = ['Brain', 'Body']

x_values = df[['Brain']]
y_values = df[['Body']]
plt.scatter(x_values, y_values)

# %%
#train model on data
body_reg = linear_model.LinearRegression()
body_reg.fit(x_values, y_values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#visualize results
plt.scatter(x_values, y_values)
plt.plot(x_values, body_reg.predict(x_values))
plt.show()

# %%
from sklearn.metrics import mean_squared_error
y_true = y_values
y_pred = body_reg.predict(x_values)
mean_squared_error(y_true, y_pred)
print(mean_squared_error(y_true, y_pred))
# Out:
# 6.91916380632

# %%
print(body_reg.predict(x_values), y_values)
# Out:
# [[  2.49662115]
#  [  6.12621963]
#  [  4.28721012]
#  [  2.89964019]
#  [  5.96154127]
#  [  4.86146068]
#  [  6.19842569]
#  [  3.65980619]
#  [  1.92249194]
#  [  2.7187003 ]
#  [ 12.9771793 ]
#  [  2.74697595]
#  [  5.99248672]
#  [  2.63375199]
#  [  2.31665209]
#  [  3.51320968]
#  [  2.01411476]
#  [  3.59111942]
#  [  4.36924592]
#  [  3.2992613 ]
#  [ 20.38709883]
#  [  2.45099177]
#  [  3.46551728]
#  [  2.54176511]
#  [ 18.77914872]
#  [ 11.35588017]
#  [  9.08533326]
#  [ 11.77819461]
#  [ 22.73288567]
#  [  2.16253159]
#  [  3.78504427]
#  [  7.01162371]
#  [  2.93847371]
#  [  5.75305385]
#  [  5.41605178]
#  [  5.61325321]
#  [  2.59200596]
#  [ 11.36558855]
#  [  3.49864712]
#  [  2.35002464]
#  [  4.14073497]
#  [  9.99670724]
#  [  2.79515377]
#  [  5.28413919]
#  [  4.39630802]
#  [  1.94142328]
#  [  2.82876903]
#  [  9.98699887]
#  [  2.51348946]
#  [  4.938885  ]
#  [  2.22964075]
#  [  4.79774945]
#  [  5.01521712]
#  [  3.47364804]
#  [  3.50532163]
#  [  3.40253418]
#  [  2.63253844]
#  [  7.08686364]
#  [  7.26088631]
#  [  6.49853593]
#  [  2.07382129]
#  [ 21.61156801]
#  [ 13.88005846]
#  [ 18.79613838]
#  [  4.54812278]
#  [  5.85499182]
#  [  8.21036569]
#  [  2.46227776]
#  [ 20.47326069]
#  [  8.08901096]
#  [  4.68925833]
#  [  3.07730351]
#  [  4.5574671 ]
#  [  1.88887669]
#  [  3.73468206]
#  [  4.93694332]
#  [  1.90052674]
#  [  8.25648048]
#  [  1.9869313 ]
#  [  2.74115092]
#  [  2.08486457]
#  [  3.50143828]
#  [  7.64327505]
#  [  3.69584855]
#  [  6.12452067]
#  [  6.92910249]
#  [  3.07220661]
#  [  2.48776226]
#  [  1.92831697]
#  [  2.71505966]
#  [  5.05587095]
#  [  2.91286786]
#  [  2.2268496 ]
#  [  5.85292879]
#  [ 12.04274791]
#  [  2.38643106]]         Body
# 0    9.13020
# 1   13.66200
# 2   11.85400
# 3    6.82330
# 4   11.88600
# 5    4.34830
# 6   12.00000
# 7    6.59870
# 8    3.81660
# 9    3.25220
# 10  15.50500
# 11   3.15510
# 12   7.22580
# 13   0.71618
# 14   3.51290
# 15   5.30480
# 16   0.56077
# 17   3.65180
# 18   5.38930
# 19   3.13860
# 20  21.76700
# 21   4.26300
# 22   5.18750
# 23   3.08250
# 24  22.63800
# 25  13.50100
# 26   7.04670
# 27  14.69200
# 28  24.14700
# 29  -1.22000
# ..       ...
# 66   7.77540
# 67   1.01730
# 68  20.99200
# 69   6.67990
# 70   4.02590
# 71   1.27840
# 72   3.34110
# 73  -2.68070
# 74   0.29678
# 75   3.88450
# 76   5.70140
# 77   6.75260
# 78   2.05760
# 79   0.47953
# 80   0.20421
# 81   0.67861
# 82   7.54350
# 83   5.34360
# 84   4.24150
# 85   6.79810
# 86   0.92695
# 87   0.15200
# 88   2.82140
# 89   1.84510
# 90   4.29590
# 91   7.20290
# 92   1.98690
# 93   0.14454
# 94   9.05510
# 95   0.61705
#
# [96 rows x 1 columns]

# %%
#read data
dataframe = pd.read_fwf('brain_body.txt')
x_values = dataframe[['Brain']]
y_values = dataframe[['Body']]

#train model on data
body_reg = linear_model.LinearRegression()
body_reg.fit(x_values, y_values)

#visualize results
plt.scatter(x_values, y_values)
plt.plot(x_values, body_reg.predict(x_values))
plt.show()
